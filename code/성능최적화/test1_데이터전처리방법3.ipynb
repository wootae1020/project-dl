# %%
# 📦 라이브러리 불러오기
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, Input
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_squared_error, r2_score
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# 📁 데이터 불러오기
df = pd.read_parquet('prepro_data.parquet')
df1 = df[df['호선'] == 2].copy()
cols = ['연도', '호선','상하구분','AWS지점코드']
for col in cols:
    df1[col] = df1[col].astype('category')

# %%
# 시 (0~23 기준)
df1['시_sin'] = np.sin(2 * np.pi * df1['시'] / 24)
df1['시_cos'] = np.cos(2 * np.pi * df1['시'] / 24)

# 요일 (0~6 기준, 월~일)
df1['요일_sin'] = np.sin(2 * np.pi * df1['요일'] / 7)
df1['요일_cos'] = np.cos(2 * np.pi * df1['요일'] / 7)

# 월, 일 (1~12, 1~31 기준)
le = LabelEncoder()
df1['월'] = le.fit_transform(df1['월'])
df1['일'] = le.fit_transform(df1['일'])

# 1. float64 → float32
float_cols = df1.select_dtypes(include=['float64']).columns
df1[float_cols] = df1[float_cols].astype('float32')

# 2. int64 → int32
int_cols = df1.select_dtypes(include=['int64']).columns
df1[int_cols] = df1[int_cols].astype('int32')

# 3. object(문자열) → category
obj_cols = df1.select_dtypes(include=['object']).columns
df1[obj_cols] = df1[obj_cols].astype('category')    
    
df1 = df1.drop(['시', '요일'], axis=1)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1868722 entries, 950460 to 12006245
# Data columns (total 27 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   시간        datetime64[ns]
#  1   호선        category
#  2   역번호       int32
#  3   역명        category
#  4   상하구분      category
#  5   AWS지점코드   category
#  6   기온        float32
#  7   풍향        float32
#  8   풍속        float32
#  9   일강수량      float32
#  10  시간강수량     float32
#  11  상대습도      float32
#  12  체감온도      float32
#  13  혼잡도       float32
#  14  승차총승객수    float32
#  15  하차총승객수    float32
#  16  미세먼지      float32
#  17  연도        category
#  18  월         int32
#  19  일         int32
#  20  주말        int32
#  21  공휴일       int32
#  22  일사량_측정여부  int32
#  23  시_sin     float32
#  24  시_cos     float32
#  25  요일_sin    float32
#  26  요일_cos    float32
# dtypes: category(5), datetime64[ns](1), float32(15), int32(6)
# memory usage: 188.9 MB

# %%
# ✅ [1] 피처 구성 및 전처리 --------------------------------------------------------

# 🎯 타겟 변수 '혼잡도' 제거하여 X 생성
X = df1.drop(['혼잡도', '시간'], axis=1)

# 🔤 범주형 변수 원-핫 인코딩 (첫 번째 카테고리는 drop)
o_h_e_x = pd.get_dummies(X, columns=['연도', '역명', '호선', '상하구분', 'AWS지점코드'], drop_first=True)

# 🔢 X 정규화 (0~1 범위로 스케일링)
mm = MinMaxScaler()
mm_x = mm.fit_transform(o_h_e_x)

# 🎯 y 정규화 (표준화: 평균 0, 표준편차 1)
y = df1[['혼잡도']]  # 2D로 유지
ss = StandardScaler()
ss_y = ss.fit_transform(y)

# %%
# ✅ [2] 시계열 학습/검증 데이터 분할 --------------------------------------------------

# 전체의 80%를 학습용, 나머지 20%를 검증용으로 사용
split_index = int(len(mm_x) * 0.8)

train_x = mm_x[:split_index]
train_y = ss_y[:split_index]

val_x = mm_x[split_index:]
val_y = ss_y[split_index:]

# %%
# ✅ [3] 시계열 데이터 생성 -----------------------------------------------------------

# 과거 21시간 데이터를 기반으로 예측
sequence_length = 21
batch_size = 128

# TimeseriesGenerator를 통해 시계열 학습/검증셋 생성
train_gen = TimeseriesGenerator(train_x, train_y, length=sequence_length, batch_size=batch_size)
val_gen   = TimeseriesGenerator(val_x, val_y, length=sequence_length, batch_size=batch_size)

# ✅ [4] LSTM 모델 정의 및 학습 --------------------------------------------------------

# 딥러닝 모델 구조 정의
model = Sequential([
    Input(shape=(sequence_length, train_x.shape[1])),  # (timesteps, features)
    LSTM(64, return_sequences=True),   # 첫 번째 LSTM: 시퀀스 출력 유지
    Dropout(0.2),
    LSTM(32),                          # 두 번째 LSTM: 최종 출력만 반환
    Dropout(0.2),
    Dense(1)                           # 예측값 하나 출력 (혼잡도)
])

# %%
# 모델 컴파일
model.compile(loss='mse', optimizer=Adam(0.001))

# 콜백 설정
callbacks = [
    ModelCheckpoint(
        filepath='prepro_data_Line1.weights.h5',      # 저장할 경로
        monitor='val_loss',            # 기준 지표
        save_best_only=True,           # 가장 성능 좋은 모델만 저장
        save_weights_only=True,        # 전체 모델이 아니라 가중치만 저장
        verbose=1
    ),
    EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', patience=2, factor=0.5)
]

# 모델 학습
history = model.fit(train_gen, validation_data=val_gen, epochs=50, callbacks=callbacks)
# Out:
# Epoch 1/50
# C:\Users\User\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 11680/11680 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.2986
# Epoch 1: val_loss improved from inf to 0.11271, saving model to prepro_data_Line1.weights.h5
# 11680/11680 ━━━━━━━━━━━━━━━━━━━━ 444s 38ms/step - loss: 0.2986 - val_loss: 0.1127 - learning_rate: 0.0010
# Epoch 2/50
# 11679/11680 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0944
# Epoch 2: val_loss improved from 0.11271 to 0.09815, saving model to prepro_data_Line1.weights.h5
# 11680/11680 ━━━━━━━━━━━━━━━━━━━━ 415s 35ms/step - loss: 0.0944 - val_loss: 0.0982 - learning_rate: 0.0010
# Epoch 3/50
# 11678/11680 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0734
# Epoch 3: val_loss improved from 0.09815 to 0.08727, saving model to prepro_data_Line1.weights.h5
# 11680/11680 ━━━━━━━━━━━━━━━━━━━━ 318s 27ms/step - loss: 0.0734 - val_loss: 0.0873 - learning_rate: 0.0010
# Epoch 4/50
# 11678/11680 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0618
# Epoch 4: val_loss improved from 0.08727 to 0.07154, saving model to prepro_data_Line1.weights.h5
# 11680/11680 ━━━━━━━━━━━━━━━━━━━━ 292s 25ms/step - loss: 0.0618 - val_loss: 0.0715 - learning_rate: 0.0010
# Epoch 5/50
# 11679/11680 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0557
# Epoch 5: val_loss improved from 0.07154 to 0.06859, saving model to prepro_data_Line1.weights.h5
# 11680/11680 ━━━━━━━━━━━━━━━━━━━━ 312s 27ms/step - loss: 0.0557 - val_loss: 0.0686 - learning_rate: 0.0010
# Epoch 6/50
# 11680/11680 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0520
# Epoch 6: val_loss improved from 0.06859 to 0.06508, saving model to prepro_data_Line1.weights.h5
# 11680/11680 ━━━━━━━━━━━━━━━━━━━━ 287s 25ms/step - loss: 0.0520 - val_loss: 0.0651 - learning_rate: 0.0010
# Epoch 7/50
# 11679/11680 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0503
# Epoch 7: val_loss did not improve from 0.06508
# 11680/11680 ━━━━━━━━━━━━━━━━━━━━ 289s 25ms/step - loss: 0.0503 - val_loss: 0.0747 - learning_rate: 0.0010
# Epoch 8/50
# 11680/11680 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0486
# Epoch 8: val_loss improved from 0.06508 to 0.06113, saving model to prepro_data_Line1.weights.h5
# 11680/11680 ━━━━━━━━━━━━━━━━━━━━ 296s 25ms/step - loss: 0.0486 - val_loss: 0.0611 - learning_rate: 0.0010
# Epoch 9/50
# 11680/11680 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0455
# Epoch 9: val_loss did not improve from 0.06113
# 11680/11680 ━━━━━━━━━━━━━━━━━━━━ 287s 25ms/step - loss: 0.0455 - val_loss: 0.0647 - learning_rate: 0.0010
# Epoch 10/50
# 11679/11680 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0435
# Epoch 10: val_loss did not improve from 0.06113
# 11680/11680 ━━━━━━━━━━━━━━━━━━━━ 288s 25ms/step - loss: 0.0435 - val_loss: 0.0681 - learning_rate: 0.0010
# Epoch 11/50
# 11679/11680 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0382
# Epoch 11: val_loss improved from 0.06113 to 0.06104, saving model to prepro_data_Line1.weights.h5
# 11680/11680 ━━━━━━━━━━━━━━━━━━━━ 296s 25ms/step - loss: 0.0382 - val_loss: 0.0610 - learning_rate: 5.0000e-04
# Epoch 12/50
# 11678/11680 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0362
# Epoch 12: val_loss improved from 0.06104 to 0.05805, saving model to prepro_data_Line1.weights.h5
# 11680/11680 ━━━━━━━━━━━━━━━━━━━━ 290s 25ms/step - loss: 0.0362 - val_loss: 0.0581 - learning_rate: 5.0000e-04
# Epoch 13/50
# 11680/11680 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0352
# Epoch 13: val_loss did not improve from 0.05805
# 11680/11680 ━━━━━━━━━━━━━━━━━━━━ 280s 24ms/step - loss: 0.0352 - val_loss: 0.0625 - learning_rate: 5.0000e-04
# Epoch 14/50
# 11678/11680 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0342
# Epoch 14: val_loss did not improve from 0.05805
# 11680/11680 ━━━━━━━━━━━━━━━━━━━━ 281s 24ms/step - loss: 0.0342 - val_loss: 0.0659 - learning_rate: 5.0000e-04
# Epoch 15/50
# 11679/11680 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0327
# Epoch 15: val_loss improved from 0.05805 to 0.05699, saving model to prepro_data_Line1.weights.h5
# 11680/11680 ━━━━━━━━━━━━━━━━━━━━ 277s 24ms/step - loss: 0.0327 - val_loss: 0.0570 - learning_rate: 2.5000e-04
# Epoch 16/50
# 11680/11680 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0324
# Epoch 16: val_loss improved from 0.05699 to 0.05625, saving model to prepro_data_Line1.weights.h5
# 11680/11680 ━━━━━━━━━━━━━━━━━━━━ 284s 24ms/step - loss: 0.0324 - val_loss: 0.0563 - learning_rate: 2.5000e-04
# Epoch 17/50
# 11680/11680 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0312
# Epoch 17: val_loss improved from 0.05625 to 0.05486, saving model to prepro_data_Line1.weights.h5
# 11680/11680 ━━━━━━━━━━━━━━━━━━━━ 290s 25ms/step - loss: 0.0312 - val_loss: 0.0549 - learning_rate: 2.5000e-04
# Epoch 18/50
# 11679/11680 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0312
# Epoch 18: val_loss did not improve from 0.05486
# 11680/11680 ━━━━━━━━━━━━━━━━━━━━ 299s 26ms/step - loss: 0.0312 - val_loss: 0.0550 - learning_rate: 2.5000e-04
# Epoch 19/50
# 11679/11680 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0315
# Epoch 19: val_loss improved from 0.05486 to 0.05428, saving model to prepro_data_Line1.weights.h5
# 11680/11680 ━━━━━━━━━━━━━━━━━━━━ 298s 25ms/step - loss: 0.0315 - val_loss: 0.0543 - learning_rate: 2.5000e-04
# Epoch 20/50
# 11678/11680 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0305
# Epoch 20: val_loss improved from 0.05428 to 0.05388, saving model to prepro_data_Line1.weights.h5
# 11680/11680 ━━━━━━━━━━━━━━━━━━━━ 299s 26ms/step - loss: 0.0305 - val_loss: 0.0539 - learning_rate: 2.5000e-04
# Epoch 21/50
# 11679/11680 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0309
# Epoch 21: val_loss did not improve from 0.05388
# 11680/11680 ━━━━━━━━━━━━━━━━━━━━ 326s 28ms/step - loss: 0.0309 - val_loss: 0.0545 - learning_rate: 2.5000e-04
# Epoch 22/50
# 11679/11680 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0305
# Epoch 22: val_loss did not improve from 0.05388
# 11680/11680 ━━━━━━━━━━━━━━━━━━━━ 439s 38ms/step - loss: 0.0305 - val_loss: 0.0539 - learning_rate: 2.5000e-04
# Epoch 23/50
# 11680/11680 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0295
# Epoch 23: val_loss improved from 0.05388 to 0.05306, saving model to prepro_data_Line1.weights.h5
# 11680/11680 ━━━━━━━━━━━━━━━━━━━━ 518s 44ms/step - loss: 0.0295 - val_loss: 0.0531 - learning_rate: 1.2500e-04
# Epoch 24/50
# 11680/11680 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0295
# Epoch 24: val_loss did not improve from 0.05306
# 11680/11680 ━━━━━━━━━━━━━━━━━━━━ 333s 29ms/step - loss: 0.0295 - val_loss: 0.0548 - learning_rate: 1.2500e-04
# Epoch 25/50
# 11680/11680 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0292
# Epoch 25: val_loss improved from 0.05306 to 0.05170, saving model to prepro_data_Line1.weights.h5
# 11680/11680 ━━━━━━━━━━━━━━━━━━━━ 328s 28ms/step - loss: 0.0292 - val_loss: 0.0517 - learning_rate: 1.2500e-04
# Epoch 26/50
# 11678/11680 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0290
# Epoch 26: val_loss did not improve from 0.05170
# 11680/11680 ━━━━━━━━━━━━━━━━━━━━ 333s 28ms/step - loss: 0.0290 - val_loss: 0.0529 - learning_rate: 1.2500e-04
# Epoch 27/50
# 11679/11680 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0295
# Epoch 27: val_loss did not improve from 0.05170
# 11680/11680 ━━━━━━━━━━━━━━━━━━━━ 331s 28ms/step - loss: 0.0295 - val_loss: 0.0535 - learning_rate: 1.2500e-04
# Epoch 28/50
# 11679/11680 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0288
# Epoch 28: val_loss improved from 0.05170 to 0.05109, saving model to prepro_data_Line1.weights.h5
# 11680/11680 ━━━━━━━━━━━━━━━━━━━━ 334s 29ms/step - loss: 0.0288 - val_loss: 0.0511 - learning_rate: 6.2500e-05
# Epoch 29/50
# 11680/11680 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0289
# Epoch 29: val_loss did not improve from 0.05109
# 11680/11680 ━━━━━━━━━━━━━━━━━━━━ 326s 28ms/step - loss: 0.0289 - val_loss: 0.0515 - learning_rate: 6.2500e-05
# Epoch 30/50
# 11679/11680 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0290
# Epoch 30: val_loss did not improve from 0.05109
# 11680/11680 ━━━━━━━━━━━━━━━━━━━━ 315s 27ms/step - loss: 0.0290 - val_loss: 0.0516 - learning_rate: 6.2500e-05
# Epoch 31/50
# 11678/11680 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0283
# Epoch 31: val_loss did not improve from 0.05109
# 11680/11680 ━━━━━━━━━━━━━━━━━━━━ 319s 27ms/step - loss: 0.0283 - val_loss: 0.0515 - learning_rate: 3.1250e-05

# %%
# 📊 학습 및 검증 손실 시각화
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss During Training')
plt.xlabel('Epoch')
plt.ylabel('Loss (MSE)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# ✅ [5] 예측 및 평가 ---------------------------------------------------------------

# 최고 성능의 가중치 로드
model.load_weights('prepro_data_Line1.weights.h5')

# 검증셋에 대해 예측 수행
pred_scaled = model.predict(val_gen)

# 정규화 해제 (역정규화) → 실제 혼잡도 단위로 복원
pred = ss.inverse_transform(pred_scaled)

# 실제 y도 시계열 슬라이싱 기준에 맞게 자르기
true = ss.inverse_transform(val_y[sequence_length:])
# Out:
# 2920/2920 ━━━━━━━━━━━━━━━━━━━━ 38s 13ms/step

# %%
# 평가 지표 계산
rmse = mean_squared_error(true, pred, squared=False)  # RMSE
r2 = r2_score(true, pred)                             # R² Score

# 결과 출력
print(f"✅ 검증 RMSE: {rmse:.4f}")
print(f"✅ R² Score: {r2:.4f}")
# Out:
# ✅ 검증 RMSE: 4.5965
# ✅ R² Score: 0.9623
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
