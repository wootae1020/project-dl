# %%
# 📦 라이브러리 불러오기
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, Input
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_squared_error, r2_score
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# 📁 데이터 불러오기
df = pd.read_parquet('/content/drive/MyDrive/공모전/prepro_data_2.parquet')
df1 = df[df['호선'] == 2].copy()
cols = ['연도', '호선','상하구분','AWS지점코드']
for col in cols:
    df1[col] = df1[col].astype('category')

# 시 (0~23 기준)
df1['시_sin'] = np.sin(2 * np.pi * df1['시'] / 24)
df1['시_cos'] = np.cos(2 * np.pi * df1['시'] / 24)

# 요일 (0~6 기준, 월~일)
df1['요일_sin'] = np.sin(2 * np.pi * df1['요일'] / 7)
df1['요일_cos'] = np.cos(2 * np.pi * df1['요일'] / 7)

# 월, 일 (1~12, 1~31 기준)
le = LabelEncoder()
df1['월'] = le.fit_transform(df1['월'])
df1['일'] = le.fit_transform(df1['일'])

# 1. float64 → float32
float_cols = df1.select_dtypes(include=['float64']).columns
df1[float_cols] = df1[float_cols].astype('float32')

# 2. int64 → int32
int_cols = df1.select_dtypes(include=['int64']).columns
df1[int_cols] = df1[int_cols].astype('int32')

# 3. object(문자열) → category
obj_cols = df1.select_dtypes(include=['object']).columns
df1[obj_cols] = df1[obj_cols].astype('category')

df1 = df1.drop(['시', '요일'], axis=1)
df1.info()

# ✅ [1] 피처 구성 및 전처리 --------------------------------------------------------

# 🎯 타겟 변수 '혼잡도' 제거하여 X 생성
X = df1.drop(['혼잡도', '시간'], axis=1)

# 🔤 범주형 변수 원-핫 인코딩 (첫 번째 카테고리는 drop)
o_h_e_x = pd.get_dummies(X, columns=['연도', '역명', '호선', '상하구분', 'AWS지점코드'], drop_first=True)

# 🔢 X 정규화 (0~1 범위로 스케일링)
mm = MinMaxScaler()
mm_x = mm.fit_transform(o_h_e_x)

# 🎯 y 정규화 (표준화: 평균 0, 표준편차 1)
y = df1[['혼잡도']]  # 2D로 유지
ss = StandardScaler()
ss_y = ss.fit_transform(y)

# ✅ [2] 시계열 학습/검증 데이터 분할 --------------------------------------------------

# 전체의 80%를 학습용, 나머지 20%를 검증용으로 사용
split_index = int(len(mm_x) * 0.8)

train_x = mm_x[:split_index]
train_y = ss_y[:split_index]

val_x = mm_x[split_index:]
val_y = ss_y[split_index:]

# ✅ [3] 시계열 데이터 생성 -----------------------------------------------------------

# 과거 21시간 데이터를 기반으로 예측
sequence_length = 21
batch_size = 128

# TimeseriesGenerator를 통해 시계열 학습/검증셋 생성
train_gen = TimeseriesGenerator(train_x, train_y, length=sequence_length, batch_size=batch_size)
val_gen   = TimeseriesGenerator(val_x, val_y, length=sequence_length, batch_size=batch_size)

# ✅ [4] LSTM 모델 정의 및 학습 --------------------------------------------------------

# 딥러닝 모델 구조 정의
model = Sequential([
    Input(shape=(sequence_length, train_x.shape[1])),  # (timesteps, features)
    LSTM(64, return_sequences=True),   # 첫 번째 LSTM: 시퀀스 출력 유지
    Dropout(0.2),
    LSTM(32),                          # 두 번째 LSTM: 최종 출력만 반환
    Dropout(0.2),
    Dense(1)                           # 예측값 하나 출력 (혼잡도)
])

# 모델 컴파일
model.compile(loss='mse', optimizer=Adam(0.001))

# 콜백 설정
callbacks = [
    ModelCheckpoint(
        filepath='prepro_data_Line1.weights.h5',      # 저장할 경로
        monitor='val_loss',            # 기준 지표
        save_best_only=True,           # 가장 성능 좋은 모델만 저장
        save_weights_only=True,        # 전체 모델이 아니라 가중치만 저장
        verbose=1
    ),
    EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', patience=2, factor=0.5)
]

# 모델 학습
history = model.fit(train_gen, validation_data=val_gen, epochs=50, callbacks=callbacks)

# 📊 학습 및 검증 손실 시각화
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss During Training')
plt.xlabel('Epoch')
plt.ylabel('Loss (MSE)')
plt.legend()
plt.grid(True)
plt.show()

# ✅ [5] 예측 및 평가 ---------------------------------------------------------------

# 최고 성능의 가중치 로드
model.load_weights('prepro_data_Line1.weights.h5')

# 검증셋에 대해 예측 수행
pred_scaled = model.predict(val_gen)

# 정규화 해제 (역정규화) → 실제 혼잡도 단위로 복원
pred = ss.inverse_transform(pred_scaled)

# 실제 y도 시계열 슬라이싱 기준에 맞게 자르기
true = ss.inverse_transform(val_y[sequence_length:])

# 평가 지표 계산
rmse = np.sqrt(mean_squared_error(true, pred))   # RMSE
r2 = r2_score(true, pred)                             # R² Score

# 결과 출력
print(f"✅ 검증 RMSE: {rmse:.4f}")
print(f"✅ R² Score: {r2:.4f}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1885624 entries, 950460 to 12006245
# Data columns (total 27 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   시간        datetime64[ns]
#  1   호선        category
#  2   역번호       int32
#  3   역명        category
#  4   상하구분      category
#  5   AWS지점코드   category
#  6   기온        float32
#  7   풍향        float32
#  8   풍속        float32
#  9   일강수량      float32
#  10  시간강수량     float32
#  11  상대습도      float32
#  12  체감온도      float32
#  13  혼잡도       float32
#  14  승차총승객수    float32
#  15  하차총승객수    float32
#  16  미세먼지      float32
#  17  연도        category
#  18  월         int32
#  19  일         int32
#  20  주말        int32
#  21  공휴일       int32
#  22  일사량_측정여부  int32
#  23  시_sin     float32
#  24  시_cos     float32
#  25  요일_sin    float32
#  26  요일_cos    float32
# dtypes: category(5), datetime64[ns](1), float32(15), int32(6)
# memory usage: 190.6 MB
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 11781/11785 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2878
# Epoch 1: val_loss improved from inf to 0.12544, saving model to prepro_data_Line1.weights.h5
# 11785/11785 ━━━━━━━━━━━━━━━━━━━━ 111s 9ms/step - loss: 0.2877 - val_loss: 0.1254 - learning_rate: 0.0010
# Epoch 2/50
# 11781/11785 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0890
# Epoch 2: val_loss improved from 0.12544 to 0.09885, saving model to prepro_data_Line1.weights.h5
# 11785/11785 ━━━━━━━━━━━━━━━━━━━━ 106s 9ms/step - loss: 0.0890 - val_loss: 0.0989 - learning_rate: 0.0010
# Epoch 3/50
# 11779/11785 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0734
# Epoch 3: val_loss improved from 0.09885 to 0.08726, saving model to prepro_data_Line1.weights.h5
# 11785/11785 ━━━━━━━━━━━━━━━━━━━━ 107s 9ms/step - loss: 0.0734 - val_loss: 0.0873 - learning_rate: 0.0010
# Epoch 4/50
# 11780/11785 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0627
# Epoch 4: val_loss improved from 0.08726 to 0.06978, saving model to prepro_data_Line1.weights.h5
# 11785/11785 ━━━━━━━━━━━━━━━━━━━━ 107s 9ms/step - loss: 0.0627 - val_loss: 0.0698 - learning_rate: 0.0010
# Epoch 5/50
# 11784/11785 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0581
# Epoch 5: val_loss improved from 0.06978 to 0.06669, saving model to prepro_data_Line1.weights.h5
# 11785/11785 ━━━━━━━━━━━━━━━━━━━━ 107s 9ms/step - loss: 0.0581 - val_loss: 0.0667 - learning_rate: 0.0010
# Epoch 6/50
# 11781/11785 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0531
# Epoch 6: val_loss did not improve from 0.06669
# 11785/11785 ━━━━━━━━━━━━━━━━━━━━ 107s 9ms/step - loss: 0.0531 - val_loss: 0.0697 - learning_rate: 0.0010
# Epoch 7/50
# 11784/11785 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0487
# Epoch 7: val_loss did not improve from 0.06669
# 11785/11785 ━━━━━━━━━━━━━━━━━━━━ 112s 10ms/step - loss: 0.0487 - val_loss: 0.0687 - learning_rate: 0.0010
# Epoch 8/50
# 11782/11785 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0424
# Epoch 8: val_loss improved from 0.06669 to 0.06231, saving model to prepro_data_Line1.weights.h5
# 11785/11785 ━━━━━━━━━━━━━━━━━━━━ 108s 9ms/step - loss: 0.0424 - val_loss: 0.0623 - learning_rate: 5.0000e-04
# Epoch 9/50
# 11782/11785 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0397
# Epoch 9: val_loss did not improve from 0.06231
# 11785/11785 ━━━━━━━━━━━━━━━━━━━━ 107s 9ms/step - loss: 0.0397 - val_loss: 0.0652 - learning_rate: 5.0000e-04
# Epoch 10/50
# 11779/11785 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0380
# Epoch 10: val_loss improved from 0.06231 to 0.05899, saving model to prepro_data_Line1.weights.h5
# 11785/11785 ━━━━━━━━━━━━━━━━━━━━ 108s 9ms/step - loss: 0.0380 - val_loss: 0.0590 - learning_rate: 5.0000e-04
# Epoch 11/50
# 11785/11785 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0358
# Epoch 11: val_loss did not improve from 0.05899
# 11785/11785 ━━━━━━━━━━━━━━━━━━━━ 108s 9ms/step - loss: 0.0358 - val_loss: 0.0618 - learning_rate: 5.0000e-04
# Epoch 12/50
# 11783/11785 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0350
# Epoch 12: val_loss did not improve from 0.05899
# 11785/11785 ━━━━━━━━━━━━━━━━━━━━ 108s 9ms/step - loss: 0.0350 - val_loss: 0.0632 - learning_rate: 5.0000e-04
# Epoch 13/50
# 11783/11785 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0323
# Epoch 13: val_loss improved from 0.05899 to 0.05705, saving model to prepro_data_Line1.weights.h5
# 11785/11785 ━━━━━━━━━━━━━━━━━━━━ 108s 9ms/step - loss: 0.0323 - val_loss: 0.0571 - learning_rate: 2.5000e-04
# Epoch 14/50
# 11785/11785 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0316
# Epoch 14: val_loss improved from 0.05705 to 0.05667, saving model to prepro_data_Line1.weights.h5
# 11785/11785 ━━━━━━━━━━━━━━━━━━━━ 109s 9ms/step - loss: 0.0316 - val_loss: 0.0567 - learning_rate: 2.5000e-04
# Epoch 15/50
# 11785/11785 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0314
# Epoch 15: val_loss improved from 0.05667 to 0.05283, saving model to prepro_data_Line1.weights.h5
# 11785/11785 ━━━━━━━━━━━━━━━━━━━━ 108s 9ms/step - loss: 0.0314 - val_loss: 0.0528 - learning_rate: 2.5000e-04
# Epoch 16/50
# 11779/11785 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0309
# Epoch 16: val_loss did not improve from 0.05283
# 11785/11785 ━━━━━━━━━━━━━━━━━━━━ 107s 9ms/step - loss: 0.0309 - val_loss: 0.0546 - learning_rate: 2.5000e-04
# Epoch 17/50
# 11782/11785 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0308
# Epoch 17: val_loss did not improve from 0.05283
# 11785/11785 ━━━━━━━━━━━━━━━━━━━━ 107s 9ms/step - loss: 0.0308 - val_loss: 0.0565 - learning_rate: 2.5000e-04
# Epoch 18/50
# 11783/11785 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0301
# Epoch 18: val_loss did not improve from 0.05283
# 11785/11785 ━━━━━━━━━━━━━━━━━━━━ 107s 9ms/step - loss: 0.0301 - val_loss: 0.0544 - learning_rate: 1.2500e-04
# 2947/2947 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step
# ✅ 검증 RMSE: 4.6741
# ✅ R² Score: 0.9610
